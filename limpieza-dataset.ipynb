# %% [markdown]
# ## Data Preprocessing

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("./Input/train.csv")

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   0.30  Very Good     F     VS2   62.8   56.0  4.29  4.31  2.70    605
# 1   1   0.34      Ideal     E     SI1   62.6   55.0  4.46  4.49  2.80    565
# 2   2   0.40  Very Good     D     SI1   60.3   62.0  4.70  4.75  2.85    720
# 3   3   0.40    Premium     H     VS1   61.8   59.2  4.72  4.74  2.92    793
# 4   4   0.90  Very Good     D     SI1   61.0   63.0  6.10  6.13  3.73   4381

# %%
#Analizamos tamaño dataset
data.shape
# Out:
# (40455, 11)

# %%
# Vemos la distribución del precio-->A medida que aumenta el precio se dispersan más los datos

import seaborn as sns
x = data["price"]
sns.distplot(x, bins=50)
sns.set(rc={'figure.figsize':(15,15)})
sns.set_style('ticks')

# %%
# Analizamos valores nulos --> No hay ningun valor nulo
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
# Analizamos datatypes--> Hay tres variables categóricas
data.dtypes
# Out:
# id           int64
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
# Eliminamos columna de id (no aporta información)
data = data.drop(["id"], axis=1)

# %%
# Analizamos la correlación entre las variables

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


def Graphs(data):
    sns.set(style="ticks", color_codes=True)
    graph = sns.pairplot(data)
    return graph, data.describe()

plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True)

# %%
print(data["cut"].unique())
print(data["color"].unique())
print(data["clarity"].unique())
# Out:
# ['Very Good' 'Ideal' 'Premium' 'Good' 'Fair']
# ['F' 'E' 'D' 'H' 'G' 'J' 'I']
# ['VS2' 'SI1' 'VS1' 'SI2' 'VVS2' 'VVS1' 'IF' 'I1']

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
data["cut"] = le.fit_transform(data["cut"])
data["color"] = le.fit_transform(data["color"])
data["clarity"] = le.fit_transform(data["clarity"])

# %%
#data['cut']=data['cut'].map({'Ideal':4,'Good':2,'Very Good':3,'Fair':1,'Premium':5})
#data['color']=data['color'].map({'F':1, 'E':2, 'D':3,'H':4, 'G':5, 'J':6, 'I':7})
#data['clarity']=data['clarity'].map({'VS2':1, 'SI1':2, 'VS1':3, 'SI2':4, 'VVS2':5, 'VVS1':6, 'IF':7, 'I1':8})
#data = pd.get_dummies(data)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True)

# %%
#Normalizamos los datos

from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.pipeline import make_pipeline
#pipeline = [
    #StandardScaler(),
    #Normalizer(),]

#tr = make_pipeline(*pipeline)

#Xpr = tr.fit_transform(data)
#Xpr = pd.DataFrame(Xpr,columns=data.columns)

# %%
#data = data.drop(["x","y","z"], axis=1) 
#data = data.drop(["table"], axis=1)

# %% [markdown]
# columnas = [a for a in data.columns if a not in ["price"]]
# X= res[columnas]
# y = res["price"]

# %%
# Grid Search
# https://medium.com/@elutins/grid-searching-in-machine-learning-quick-explanation-and-python-implementation-550552200596

# %% [markdown]
# ### to_csv

# %%
resultado = data.to_csv('Output/dataset_limpio.csv',index=False)

# %%
#https://medium.com/qu4nt/el-machine-learning-y-la-regresi%C3%B3n-python-c94db2968a4e
